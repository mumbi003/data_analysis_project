# %%
import pandas as pd
df = pd.read_excel('C:\\Users\\SERVER\\Downloads\\customer_reviews_dataset.xlsx')

# %%
df
# Out:
#     customer_id  age  income  years_experience     city  device  \
# 0             1   23   25000                 1  Nairobi  Mobile
# 1             2   45  120000                20  Mombasa  Laptop
# 2             3   34   54000                 8   Kisumu  Tablet
# 3             4   29   48000                 5  Nairobi  Mobile
# 4             5   52  220000                25   Nakuru  Laptop
# 5             6   41   67000                12  Eldoret  Mobile
# 6             7   37   72000                10  Nairobi  Tablet
# 7             8   26   31000                 3  Mombasa  Mobile
# 8             9   48   98000                22   Kisumu  Laptop
# 9            10   31   45000                 6   Nakuru  Mobile
# 10           11   27   38000                 4  Eldoret  Tablet
# 11           12   56  300000                30  Nairobi  Laptop
# 12           13   33   52000                 7  Mombasa  Mobile
# 13           14   22   21000                 1   Kisumu  Mobile
# 14           15   39   76000                14   Nakuru  Tablet
# 15           16   44   89000                18  Eldoret  Laptop
# 16           17   28   42000                 4  Nairobi  Mobile
# 17           18   36   68000                11  Mombasa  Tablet
# 18           19   50  150000                24   Kisumu  Laptop
# 19           20   24   27000                 2   Nakuru  Mobile
#
#    product_category  rating purchased
# 0       Electronics       4       Yes
# 1              Home       5       Yes
# 2       Electronics       3        No
# 3           Fashion       4       Yes
# 4              Home       5       Yes
# 5       Electronics       2        No
# 6           Fashion       4       Yes
# 7       Electronics       3        No
# 8              Home       5       Yes
# 9           Fashion       4       Yes
# 10      Electronics       3        No
# 11             Home       5       Yes
# 12      Electronics       2        No
# 13          Fashion       4       Yes
# 14      Electronics       3        No
# 15             Home       5       Yes
# 16          Fashion       4       Yes
# 17      Electronics       3        No
# 18             Home       5       Yes
# 19          Fashion       4       Yes

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
x = df.drop(['purchased', 'customer_id'], axis=1)
y = df['purchased']

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'income', 'years_experience', 'city', 'device',
#        'product_category', 'rating', 'purchased'],
#       dtype='str')

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
cat_cols = ['city', 'device','product_category']
num_cols = ['age', 'income', 'years_experience', 'rating']

# %%
preprocessor = ColumnTransformer(
    transformers = [
        ('cat', OneHotEncoder(), cat_cols),
        ('num', StandardScaler(), num_cols)
    ]
)

# %%
from sklearn.pipeline import Pipeline
pipeline = Pipeline([
    ('preprocess', preprocessor),
    ('model', DecisionTreeClassifier())
])

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2)
pipeline.fit(X_train, Y_train)
pipeline.predict(X_test)
# Out:
# array(['No', 'No', 'Yes', 'Yes'], dtype=object)

# %%
pipeline.score(X_test, Y_test)
# Out:
# 1.0

# %%
Y_test
# Out:
# 5      No
# 2      No
# 18    Yes
# 4     Yes
# Name: purchased, dtype: str

# %%
X_test
# Out:
#     age  income  years_experience     city  device product_category  rating
# 5    41   67000                12  Eldoret  Mobile      Electronics       2
# 2    34   54000                 8   Kisumu  Tablet      Electronics       3
# 18   50  150000                24   Kisumu  Laptop             Home       5
# 4    52  220000                25   Nakuru  Laptop             Home       5
