# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('C:\\Users\\SERVER\\Downloads\\customer_reviews_dataset.xlsx')
df.head()
# Out:
#    customer_id  age  income  years_experience     city  device  \
# 0            1   23   25000                 1  Nairobi  Mobile
# 1            2   45  120000                20  Mombasa  Laptop
# 2            3   34   54000                 8   Kisumu  Tablet
# 3            4   29   48000                 5  Nairobi  Mobile
# 4            5   52  220000                25   Nakuru  Laptop
#
#   product_category  rating purchased
# 0      Electronics       4       Yes
# 1             Home       5       Yes
# 2      Electronics       3        No
# 3          Fashion       4       Yes
# 4             Home       5       Yes

# %%
plt.scatter(x=df['age'], y=df['purchased'], marker='+')

# %%
plt.scatter(x=df['income'], y=df['purchased'], marker='+')

# %%
x = df[['income']]
y = df['purchased']

# %%
x
# Out:
#     income
# 0    25000
# 1   120000
# 2    54000
# 3    48000
# 4   220000
# 5    67000
# 6    72000
# 7    31000
# 8    98000
# 9    45000
# 10   38000
# 11  300000
# 12   52000
# 13   21000
# 14   76000
# 15   89000
# 16   42000
# 17   68000
# 18  150000
# 19   27000

# %%
y
# Out:
# 0     Yes
# 1     Yes
# 2      No
# 3     Yes
# 4     Yes
# 5      No
# 6     Yes
# 7      No
# 8     Yes
# 9     Yes
# 10     No
# 11    Yes
# 12     No
# 13    Yes
# 14     No
# 15    Yes
# 16    Yes
# 17     No
# 18    Yes
# 19    Yes
# Name: purchased, dtype: str

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(df[['income']],df['purchased'] , test_size=0.2, random_state=42)

# %%
X_train
# Out:
#     income
# 8    98000
# 5    67000
# 11  300000
# 3    48000
# 18  150000
# 16   42000
# 13   21000
# 2    54000
# 9    45000
# 19   27000
# 4   220000
# 12   52000
# 7    31000
# 10   38000
# 14   76000
# 6    72000

# %%
X_test
# Out:
#     income
# 0    25000
# 17   68000
# 15   89000
# 1   120000

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array(['No', 'Yes', 'Yes', 'Yes'], dtype=object)

# %%
model.score(X_test, Y_test)
# Out:
# 0.5

# %%
from sklearn.metrics import confusion_matrix

# %%
model.predict_proba(X_test)
# Out:
# array([[0.54309965, 0.45690035],
#        [0.3821215 , 0.6178785 ],
#        [0.31010122, 0.68989878],
#        [0.2191395 , 0.7808605 ]])

# %%
X_test
# Out:
#     income
# 0    25000
# 17   68000
# 15   89000
# 1   120000
